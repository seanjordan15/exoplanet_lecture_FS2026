# %% [markdown]
# # Extrasolar Planets – Exercise 4
# ## Planetary Interiors and Atmospheric Escape
#
# In this exercise we explore how planetary composition affects planetary radius,
# and how escape velocity relates to atmospheric escape.
#
# You will:
# 1. Implement a simple two-layer interior model
# 2. Explore the effect of iron fraction on planetary radius
# 3. Compare the model with Earth
# 4. Investigate atmospheric escape

# %% [markdown]
# #Part 1: Theoretical Calculation of Radius

# %% [markdown]
# # Part 2
# #Implement a function to compute planetary radius given total mass and iron core mass fraction.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from urllib.parse import quote

# %%
# constants
M_earth = 5.97e24      # kg
R_earth = 6.371e6      # m
rho_Fe = 8000   # kg/m^3
rho_Si = 4000   # kg/m^3


def calculate_radius(M_p_EarthMass, f_Fe, rho_Fe, rho_Si):
    """
    Calculate planetary radius using a two-layer interior model.
    Returns
    -------
    R_p_EarthRadius : float or array
        Planet radius in Earth radii
    """

# %% [markdown]
# #Varying Iron Content

# %%
# HINT: call calculate_radius for given iron mass fractions

# %% [markdown]
# #Comparison to Earth

# %%
# HINT: earth_radius using calculate_radius() for Earth's mass and iron mass fraction=0.33

# %% [markdown]
# #Part 4: Theoretical

# %% [markdown]
# # Part 5:
# # Atmospheric Escape

# %% [markdown]
# # escape velocity

# %%
# ----------------------------
# Constants
# ----------------------------
G = 6.67430e-11          # m^3 kg^-1 s^-2
M_earth_kg = 5.972e24    # kg
R_earth_m = 6.371e6      # m
T_sun = 5772.0           # K

# ----------------------------
# Solar System planets + Moon
# mass and radius in Earth units
# luminosity = 1 because they orbit the Sun
# ----------------------------
planets = pd.DataFrame({
    "Planet": [
        "Mercury", "Venus", "Earth", "Moon", "Mars",
        "Jupiter", "Saturn", "Uranus", "Neptune"
    ],
    "mass_earth": [
        0.0553, 0.815, 1.0, 0.0123, 0.107,
        317.8, 95.2, 14.5, 17.1
    ],
    "radius_earth": [
        0.383, 0.949, 1.0, 0.273, 0.532,
        11.21, 9.45, 4.01, 3.88
    ]
})


# ----------------------------
# Escape velocity function
# Inputs: mass in Earth masses, radius in Earth radii
# Output: km/s
# ----------------------------

# %% [markdown]
# # query transiting exoplanets

# %%
# NASA Exoplanet Archive query:
# - only transiting planets
# - only planets with measured mass and radius

print("Number of transiting exoplanets with mass and radius:", len(exo))
# Out:
# Number of transiting exoplanets with mass and radius: 4491

# %% [markdown]
# # luminosity

# %%
#estimate luminosity from data or from relations and compute escape velocity for each planet

# %% [markdown]
# # plot

# %%
# show escape velocity vs stellar luminosity for the exoplanets and the Solar System planets

# %% [markdown]
# # finding escape-prone exoplanets

# %%
# Identify potentially escape-affected exoplanets in the plot


# look for low mass planets in the escape-prone category
